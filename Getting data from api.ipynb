# %%
import gzip
import json
import os
import pandas as pd
import requests

from io import BytesIO
from time import sleep


BASE_API_CALL = 'https://api.themoviedb.org/3/{category}/{entry_id}?api_key={api_key}{category_specifics}'
CATEGORIES = ['movie']
DOWNLOADS_PER_DISK_WRITE = 40
MAX_DOWNLOADS_PER_SECOND = 4
MAX_ATTEMPTS = 3
RATE_LIMITER_DELAY_SECONDS = 10
RATE_LIMIT_EXCEEDED_STATUS_CODE = 429
SUCCESSFUL_CALL_STATUS_CODE = 200

CATEGORY_SPECIFIC_CALLS = {
    'movie': '&append_to_response=credits,keywords',
                            }

JSON_COLUMNS = {
    'genres',
    'keywords',
    'production_countries',
    'production_companies',
    'spoken_languages'
                }

KEYS_TO_DROP = {
    'adult',
    'backdrop_path',
    'belongs_to_collection',
    'imdb_id',
    'poster_path',
    'profile_path',
    'video',
                }


def was_successful(response):
    return response.status_code == SUCCESSFUL_CALL_STATUS_CODE


def was_rate_limited(response):
    return response.status_code == RATE_LIMIT_EXCEEDED_STATUS_CODE


def make_request(call_url, prior_attempts=0):
    if prior_attempts >= MAX_ATTEMPTS:
        return None
    response = requests.get(call_url)
    if was_rate_limited(response):
        sleep(RATE_LIMITER_DELAY_SECONDS)
    sleep(1 / MAX_DOWNLOADS_PER_SECOND)
    if was_successful(response):
        return response.json()
    else:
        sleep(1)  # attempt to sleep through any intermittent issues
        return make_request(call_url, prior_attempts + 1)


def make_detail_request(category, entry_id):
    category_specifics = ''
    if category in CATEGORY_SPECIFIC_CALLS:
        category_specifics = CATEGORY_SPECIFIC_CALLS[category]
    call_url = BASE_API_CALL.format(
        category=category,
        entry_id=entry_id,
        api_key=API_KEY,
        category_specifics=category_specifics,
                                    )
    return make_request(call_url)


def load_api_key():
    return 'bf0cb24a4dbe7d1eb14b726c1313cbf5'


def make_category_id_url_suffix(category, extension='json'):
    year = str(pd.datetime.today().year)
    month = str(pd.datetime.today().month).zfill(2)
    day = str(pd.datetime.today().day - 1).zfill(2)
    return '_'.join([category, 'ids', month, day, year]) + '.' + extension


def download_id_list_as_csv(category):
    # see daily file export list docs at:
    # https://developers.themoviedb.org/3/getting-started/daily-file-exports
    print(f'Downloading list of ids for {category}')
    id_list_name = make_category_id_url_suffix(category)
    ID_LISTS_RAW_URL = 'http://files.tmdb.org/p/exports/{0}.gz'.format(id_list_name)
    with gzip.open(BytesIO(requests.get(ID_LISTS_RAW_URL).content), 'r') as f_open:
        id_list = f_open.readlines() #.decode('utf-8')
    # original 'json' is malformed, is actually one dict per line
    ids = pd.DataFrame([json.loads(x) for x in id_list])
    # some entries in the movie id list appear to be collections rather than movies
    if 'original_title' in ids.columns:
        ids.original_title = ids.original_title.apply(str)
        ids = ids[~ids.original_title.str.endswith(' Collection')].copy()
    # You have to drop adult films if you want to post any new data to Kaggle.
    if 'adult' in ids.columns:
        ids = ids[~ids['adult']].copy()
    ids.to_csv(category + '_ids.csv', index=False)


def load_id_list(category):
    if not os.path.exists(category + '_ids.csv'):
        download_id_list_as_csv(category)
    df = pd.read_csv(category + '_ids.csv')
    return df.id.values.tolist()


def unpack_credits(df):
    # credits were downloaded with the movie details to cut down on the
    # total number of requests, but it should probably be stored separately
    credits = pd.DataFrame(df[['credits', 'id', 'title']])
    credits.rename(columns={'id': 'movie_id'}, inplace=True)
    new_columns = ['cast', 'crew']
    for column in new_columns:
        credits[column] = credits['credits'].apply(
            lambda x: x[column] if column in x else [])
        credits[column] = credits[column].apply(lambda x:
            [{k: v for k, v in i.items() if k not in {'profile_path'}} for i in x])
        credits[column] = credits[column].apply(json.dumps)
    del credits['credits']
    del df['credits']
    return df, credits


def export_data(category, all_entries):
    if not all_entries:
        return None
    df = pd.DataFrame(all_entries)
    df = df[[x for x in df.columns if x not in KEYS_TO_DROP]].copy()
    
    # Drop those with no id
    if len(df[df.id.isnull()]) > 0:
        print(f'Dropping {len(df[df.id.isnull()])} entries without ids')
        df = df[~df.id.isnull()]
    # Drops entries with revenue/budget =0
    df = df.loc[(df['revenue']!=0) & (df['original_language']=='en') & (df['budget']!=0)]
    
    
    df = df[df.id.apply(lambda x: str(x).isnumeric())]
    # this section about credits is specific to the movie category
    df, credits = unpack_credits(df)
    df['keywords'] = df['keywords'].apply(lambda x:
        x['keywords'] if 'keywords' in x else [])
    for column in JSON_COLUMNS:
        df[column] = df[column].apply(json.dumps)
    needs_header = not(os.path.exists(category + '_data.csv'))
    df.to_csv(category + '_data.csv', index=False, mode='a+', header=needs_header)
    credits.to_csv(category + '_credits.csv', index=False, mode='a+', header=needs_header)


def download_ids(category, id_list):
    if os.path.exists(category + '_data.csv'):
        existing_ids = pd.read_csv(category + '_data.csv', usecols=['id'], dtype=object)
        set(existing_ids.id.values.tolist())
        id_list = [x for x in id_list if str(x) not in existing_ids]
    counter = 0
    all_entries = []
    print(f'Downloading details for {category}')
    for movie_id in id_list:
        current_data = make_detail_request(category, movie_id)
        if not current_data:
            print(f'Failed on id # {movie_id}')
            continue
        counter += 1
        all_entries.append(current_data)
        if counter % DOWNLOADS_PER_DISK_WRITE == 0:
            print(f'Finished downloading {counter} entries for {category}')
            export_data(category, all_entries)
            all_entries = []
    export_data(category, all_entries)


def download_all_data():
    for category in CATEGORIES:
        download_ids(category, load_id_list(category))


if __name__ == '__main__':
    API_KEY = load_api_key()
    download_all_data()
# Out:
# Downloading details for movie
# Finished downloading 40 entries for movie
# Finished downloading 80 entries for movie
# Finished downloading 120 entries for movie
# Finished downloading 160 entries for movie
# Finished downloading 200 entries for movie
# Finished downloading 240 entries for movie
# Finished downloading 280 entries for movie
# Finished downloading 320 entries for movie
# Finished downloading 360 entries for movie
# Finished downloading 400 entries for movie
# Finished downloading 440 entries for movie
# Finished downloading 480 entries for movie
# Finished downloading 520 entries for movie
# Finished downloading 560 entries for movie
# Finished downloading 600 entries for movie
# Finished downloading 640 entries for movie
# Finished downloading 680 entries for movie
# Finished downloading 720 entries for movie
# Finished downloading 760 entries for movie
# Finished downloading 800 entries for movie
# Finished downloading 840 entries for movie
# Finished downloading 880 entries for movie
# Finished downloading 920 entries for movie
# Finished downloading 960 entries for movie
# Finished downloading 1000 entries for movie
# Finished downloading 1040 entries for movie
# Finished downloading 1080 entries for movie
# Finished downloading 1120 entries for movie
# Finished downloading 1160 entries for movie
# Finished downloading 1200 entries for movie
# Finished downloading 1240 entries for movie
# Finished downloading 1280 entries for movie
# Finished downloading 1320 entries for movie
# Finished downloading 1360 entries for movie
# Finished downloading 1400 entries for movie
# Finished downloading 1440 entries for movie
# Finished downloading 1480 entries for movie
# Finished downloading 1520 entries for movie
# Finished downloading 1560 entries for movie
# Finished downloading 1600 entries for movie
# Finished downloading 1640 entries for movie
# Finished downloading 1680 entries for movie
# Finished downloading 1720 entries for movie
# Finished downloading 1760 entries for movie
# Finished downloading 1800 entries for movie
# Finished downloading 1840 entries for movie
# Finished downloading 1880 entries for movie
# Finished downloading 1920 entries for movie
# Finished downloading 1960 entries for movie
# Finished downloading 2000 entries for movie
# Finished downloading 2040 entries for movie
# Finished downloading 2080 entries for movie
# Finished downloading 2120 entries for movie
# Finished downloading 2160 entries for movie
# Finished downloading 2200 entries for movie
# Finished downloading 2240 entries for movie
# Finished downloading 2280 entries for movie
# Finished downloading 2320 entries for movie
# Finished downloading 2360 entries for movie
# Finished downloading 2400 entries for movie
# Finished downloading 2440 entries for movie
# Finished downloading 2480 entries for movie
# Finished downloading 2520 entries for movie
# Finished downloading 2560 entries for movie
# Finished downloading 2600 entries for movie
# Finished downloading 2640 entries for movie
# Finished downloading 2680 entries for movie
# Finished downloading 2720 entries for movie
# Finished downloading 2760 entries for movie
# Finished downloading 2800 entries for movie
# Finished downloading 2840 entries for movie
# Finished downloading 2880 entries for movie
# Finished downloading 2920 entries for movie
# Finished downloading 2960 entries for movie
# Finished downloading 3000 entries for movie
# Finished downloading 3040 entries for movie
# Finished downloading 3080 entries for movie
# Finished downloading 3120 entries for movie
# Finished downloading 3160 entries for movie
# Finished downloading 3200 entries for movie
# Finished downloading 3240 entries for movie
# Finished downloading 3280 entries for movie
# Finished downloading 3320 entries for movie
# Finished downloading 3360 entries for movie
# Finished downloading 3400 entries for movie
# Finished downloading 3440 entries for movie
# Finished downloading 3480 entries for movie
# Finished downloading 3520 entries for movie
# Finished downloading 3560 entries for movie
# Finished downloading 3600 entries for movie
# Finished downloading 3640 entries for movie
# Finished downloading 3680 entries for movie
# Finished downloading 3720 entries for movie
# Finished downloading 3760 entries for movie
# Finished downloading 3800 entries for movie
# Finished downloading 3840 entries for movie
# Finished downloading 3880 entries for movie
# Finished downloading 3920 entries for movie
# Finished downloading 3960 entries for movie
# Finished downloading 4000 entries for movie
# Finished downloading 4040 entries for movie
# Finished downloading 4080 entries for movie
# Finished downloading 4120 entries for movie
# Finished downloading 4160 entries for movie
# Finished downloading 4200 entries for movie
# Finished downloading 4240 entries for movie
# Finished downloading 4280 entries for movie
# Finished downloading 4320 entries for movie
# Finished downloading 4360 entries for movie
# Finished downloading 4400 entries for movie
# Finished downloading 4440 entries for movie
# Finished downloading 4480 entries for movie
# Finished downloading 4520 entries for movie
# Finished downloading 4560 entries for movie
# Finished downloading 4600 entries for movie
# Finished downloading 4640 entries for movie
# Finished downloading 4680 entries for movie
# Finished downloading 4720 entries for movie
# Finished downloading 4760 entries for movie
# Finished downloading 4800 entries for movie
# Finished downloading 4840 entries for movie
# Finished downloading 4880 entries for movie
# Finished downloading 4920 entries for movie
# Finished downloading 4960 entries for movie
# Finished downloading 5000 entries for movie
# Finished downloading 5040 entries for movie
# Finished downloading 5080 entries for movie
# Finished downloading 5120 entries for movie
# Finished downloading 5160 entries for movie
# Finished downloading 5200 entries for movie
# Finished downloading 5240 entries for movie
# Finished downloading 5280 entries for movie
# Finished downloading 5320 entries for movie
# Finished downloading 5360 entries for movie
# Finished downloading 5400 entries for movie
# Finished downloading 5440 entries for movie
# Finished downloading 5480 entries for movie
# Finished downloading 5520 entries for movie
# Finished downloading 5560 entries for movie
# Finished downloading 5600 entries for movie
# Finished downloading 5640 entries for movie
# Finished downloading 5680 entries for movie
# Finished downloading 5720 entries for movie
# Finished downloading 5760 entries for movie
# Finished downloading 5800 entries for movie
# Finished downloading 5840 entries for movie
# Finished downloading 5880 entries for movie
# Finished downloading 5920 entries for movie
# Finished downloading 5960 entries for movie
# Finished downloading 6000 entries for movie
# Finished downloading 6040 entries for movie
# Finished downloading 6080 entries for movie
# Finished downloading 6120 entries for movie
# Finished downloading 6160 entries for movie
# Finished downloading 6200 entries for movie
# Finished downloading 6240 entries for movie
# Finished downloading 6280 entries for movie
# Finished downloading 6320 entries for movie
# Finished downloading 6360 entries for movie
# Finished downloading 6400 entries for movie
# Finished downloading 6440 entries for movie
# Finished downloading 6480 entries for movie
# Finished downloading 6520 entries for movie
# Finished downloading 6560 entries for movie
# Finished downloading 6600 entries for movie
# Finished downloading 6640 entries for movie
# Finished downloading 6680 entries for movie
# Finished downloading 6720 entries for movie
# Finished downloading 6760 entries for movie
# Finished downloading 6800 entries for movie
# Finished downloading 6840 entries for movie
# Finished downloading 6880 entries for movie
# Finished downloading 6920 entries for movie
# Finished downloading 6960 entries for movie
# Finished downloading 7000 entries for movie
# Finished downloading 7040 entries for movie
# Finished downloading 7080 entries for movie
# Finished downloading 7120 entries for movie
# Finished downloading 7160 entries for movie
# Finished downloading 7200 entries for movie
# Finished downloading 7240 entries for movie
# Finished downloading 7280 entries for movie
# Finished downloading 7320 entries for movie
# Finished downloading 7360 entries for movie
# Finished downloading 7400 entries for movie
# Finished downloading 7440 entries for movie
# Finished downloading 7480 entries for movie
# Finished downloading 7520 entries for movie
# Finished downloading 7560 entries for movie
# Finished downloading 7600 entries for movie
# Finished downloading 7640 entries for movie
# Finished downloading 7680 entries for movie
# Finished downloading 7720 entries for movie
# Finished downloading 7760 entries for movie
# Finished downloading 7800 entries for movie
# Finished downloading 7840 entries for movie
# Finished downloading 7880 entries for movie
# Finished downloading 7920 entries for movie
# Finished downloading 7960 entries for movie
# Finished downloading 8000 entries for movie
# Finished downloading 8040 entries for movie
# Finished downloading 8080 entries for movie
# Finished downloading 8120 entries for movie
# Finished downloading 8160 entries for movie
# Finished downloading 8200 entries for movie
# Finished downloading 8240 entries for movie
# Finished downloading 8280 entries for movie
# Finished downloading 8320 entries for movie
# Finished downloading 8360 entries for movie
# Finished downloading 8400 entries for movie
# Finished downloading 8440 entries for movie
# Finished downloading 8480 entries for movie
# Finished downloading 8520 entries for movie
# Finished downloading 8560 entries for movie
# Finished downloading 8600 entries for movie
# Finished downloading 8640 entries for movie
# Finished downloading 8680 entries for movie
# Finished downloading 8720 entries for movie
# Finished downloading 8760 entries for movie
# Finished downloading 8800 entries for movie
# Finished downloading 8840 entries for movie
# Finished downloading 8880 entries for movie
# Finished downloading 8920 entries for movie
# Finished downloading 8960 entries for movie
# Finished downloading 9000 entries for movie
# Finished downloading 9040 entries for movie
# Finished downloading 9080 entries for movie
# Finished downloading 9120 entries for movie
# Finished downloading 9160 entries for movie
# Finished downloading 9200 entries for movie
# Finished downloading 9240 entries for movie
# Finished downloading 9280 entries for movie
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-8b19237f0d45> in <module>
#     186 if __name__ == '__main__':
#     187     API_KEY = load_api_key()
# --> 188     download_all_data()
#     189
#
# <ipython-input-4-8b19237f0d45> in download_all_data()
#     181 def download_all_data():
#     182     for category in CATEGORIES:
# --> 183         download_ids(category, load_id_list(category))
#     184
#     185
#
# <ipython-input-4-8b19237f0d45> in download_ids(category, id_list)
#     174         if counter % DOWNLOADS_PER_DISK_WRITE == 0:
#     175             print(f'Finished downloading {counter} entries for {category}')
# --> 176             export_data(category, all_entries)
#     177             all_entries = []
#     178     export_data(category, all_entries)
#
# <ipython-input-4-8b19237f0d45> in export_data(category, all_entries)
#     147     df = df[df.id.apply(lambda x: str(x).isnumeric())]
#     148     # this section about credits is specific to the movie category
# --> 149     df, credits = unpack_credits(df)
#     150     df['keywords'] = df['keywords'].apply(lambda x:
#     151         x['keywords'] if 'keywords' in x else [])
#
# <ipython-input-4-8b19237f0d45> in unpack_credits(df)
#     117     # credits were downloaded with the movie details to cut down on the
#     118     # total number of requests, but it should probably be stored separately
# --> 119     credits = pd.DataFrame(df[['credits', 'id', 'title']])
#     120     credits.rename(columns={'id': 'movie_id'}, inplace=True)
#     121     new_columns = ['cast', 'crew']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1263             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1264
# -> 1265         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1266         return keyarr, indexer
#    1267
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1305             if missing == len(indexer):
#    1306                 axis_name = self.obj._get_axis_name(axis)
# -> 1307                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1308
#    1309             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['credits', 'id', 'title'], dtype='object')] are in the [columns]"
