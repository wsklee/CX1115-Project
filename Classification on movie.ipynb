# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
df= pd.read_csv('movie_data.csv', encoding ='utf-8')
df.head()
# Out:
#      budget                                             genres  \
# 0   4000000  [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# 1  21000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 2  11000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 3  94000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 4  55000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
#
#                                             homepage  id original_language  \
# 0                                                NaN   5                en
# 1                                                NaN   6                en
# 2  http://www.starwars.com/films/star-wars-episod...  11                en
# 3              http://movies.disney.com/finding-nemo  12                en
# 4                                                NaN  13                en
#
#    original_title                                           overview  \
# 0      Four Rooms  It's Ted the Bellhop's first night on the job....
# 1  Judgment Night  While racing to a boxing match, Frank, Mike, J...
# 2       Star Wars  Princess Leia is captured and held hostage by ...
# 3    Finding Nemo  Nemo, an adventurous young clownfish, is unexp...
# 4    Forrest Gump  A man with a low IQ has accomplished great thi...
#
#    popularity                               production_companies  \
# 0      12.448  [{"id": 14, "logo_path": "/m6AHu84oZQxvq7n1rsv...
# 1      13.926  [{"id": 33, "logo_path": "/8lvHyhjr8oUKOOy2dKX...
# 2      62.765  [{"id": 1, "logo_path": "/o86DbpburjxrqAzEDhXZ...
# 3      72.029  [{"id": 3, "logo_path": "/1TjvGVDMYsj6JBxOAkUH...
# 4      48.489  [{"id": 4, "logo_path": "/fycMZt242LVjagMByZOL...
#
#                                 production_countries release_date    revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   1995-12-09    4257354
# 1  [{"iso_3166_1": "JP", "name": "Japan"}, {"iso_...   1993-10-15   12136938
# 2  [{"iso_3166_1": "US", "name": "United States o...   1977-05-25  775398007
# 3  [{"iso_3166_1": "US", "name": "United States o...   2003-05-30  940335536
# 4  [{"iso_3166_1": "US", "name": "United States o...   1994-07-06  677387716
#
#    runtime                                   spoken_languages    status  \
# 0     98.0  [{"english_name": "English", "iso_639_1": "en"...  Released
# 1    110.0  [{"english_name": "English", "iso_639_1": "en"...  Released
# 2    121.0  [{"english_name": "English", "iso_639_1": "en"...  Released
# 3    100.0  [{"english_name": "English", "iso_639_1": "en"...  Released
# 4    142.0  [{"english_name": "English", "iso_639_1": "en"...  Released
#
#                                              tagline           title  \
# 0  Twelve outrageous guests. Four scandalous requ...      Four Rooms
# 1     Don't move. Don't whisper. Don't even breathe.  Judgment Night
# 2       A long time ago in a galaxy far, far away...       Star Wars
# 3  There are 3.7 trillion fish in the ocean. They...    Finding Nemo
# 4  Life is like a box of chocolates...you never k...    Forrest Gump
#
#    vote_average  vote_count                                           keywords
# 0           5.7        1915  [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# 1           6.5         184  [{"id": 520, "name": "chicago, illinois"}, {"i...
# 2           8.2       15328  [{"id": 803, "name": "android"}, {"id": 4270, ...
# 3           7.8       14824  [{"id": 970, "name": "parent child relationshi...
# 4           8.5       20250  [{"id": 422, "name": "vietnam veteran"}, {"id"...

# %%
print("Data type : ", type(df))
print("Data dims : ", df.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (2932, 20)

# %%
print(df.dtypes)
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# keywords                 object
# dtype: object

# %% [markdown]
# # Simple Decision Tree
#
# We will start by setting up a simple Classification Problem.
# Extract the variables and the associated data as a Pandas DataFrame.

# %%
# Classification of what? 
# Lets try popularity. Calculate median popularity
popularity_med = df['popularity'].median()
print(popularity_med)
# Out:
# 13.9355

# %%
# Classify if popularity > median its 1, else 0.
df['isPopular'] = np.where(df['popularity']>=popularity_med, 1, 0)
df.head()
# Out:
#      budget                                             genres  \
# 0   4000000  [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# 1  21000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 2  11000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 3  94000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 4  55000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
#
#                                             homepage  id original_language  \
# 0                                                NaN   5                en
# 1                                                NaN   6                en
# 2  http://www.starwars.com/films/star-wars-episod...  11                en
# 3              http://movies.disney.com/finding-nemo  12                en
# 4                                                NaN  13                en
#
#    original_title                                           overview  \
# 0      Four Rooms  It's Ted the Bellhop's first night on the job....
# 1  Judgment Night  While racing to a boxing match, Frank, Mike, J...
# 2       Star Wars  Princess Leia is captured and held hostage by ...
# 3    Finding Nemo  Nemo, an adventurous young clownfish, is unexp...
# 4    Forrest Gump  A man with a low IQ has accomplished great thi...
#
#    popularity                               production_companies  \
# 0      12.448  [{"id": 14, "logo_path": "/m6AHu84oZQxvq7n1rsv...
# 1      13.926  [{"id": 33, "logo_path": "/8lvHyhjr8oUKOOy2dKX...
# 2      62.765  [{"id": 1, "logo_path": "/o86DbpburjxrqAzEDhXZ...
# 3      72.029  [{"id": 3, "logo_path": "/1TjvGVDMYsj6JBxOAkUH...
# 4      48.489  [{"id": 4, "logo_path": "/fycMZt242LVjagMByZOL...
#
#                                 production_countries  ...    revenue  runtime  \
# 0  [{"iso_3166_1": "US", "name": "United States o...  ...    4257354     98.0
# 1  [{"iso_3166_1": "JP", "name": "Japan"}, {"iso_...  ...   12136938    110.0
# 2  [{"iso_3166_1": "US", "name": "United States o...  ...  775398007    121.0
# 3  [{"iso_3166_1": "US", "name": "United States o...  ...  940335536    100.0
# 4  [{"iso_3166_1": "US", "name": "United States o...  ...  677387716    142.0
#
#                                     spoken_languages    status  \
# 0  [{"english_name": "English", "iso_639_1": "en"...  Released
# 1  [{"english_name": "English", "iso_639_1": "en"...  Released
# 2  [{"english_name": "English", "iso_639_1": "en"...  Released
# 3  [{"english_name": "English", "iso_639_1": "en"...  Released
# 4  [{"english_name": "English", "iso_639_1": "en"...  Released
#
#                                              tagline           title  \
# 0  Twelve outrageous guests. Four scandalous requ...      Four Rooms
# 1     Don't move. Don't whisper. Don't even breathe.  Judgment Night
# 2       A long time ago in a galaxy far, far away...       Star Wars
# 3  There are 3.7 trillion fish in the ocean. They...    Finding Nemo
# 4  Life is like a box of chocolates...you never k...    Forrest Gump
#
#   vote_average  vote_count                                           keywords  \
# 0          5.7        1915  [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# 1          6.5         184  [{"id": 520, "name": "chicago, illinois"}, {"i...
# 2          8.2       15328  [{"id": 803, "name": "android"}, {"id": 4270, ...
# 3          7.8       14824  [{"id": 970, "name": "parent child relationshi...
# 4          8.5       20250  [{"id": 422, "name": "vietnam veteran"}, {"id"...
#
#   isPopular
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1
#
# [5 rows x 21 columns]

# %%
# Correlation Matrix
print(df.corr())

# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(df.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000 -0.118317    0.393472  0.662532  0.212593
# id           -0.118317  1.000000   -0.128508 -0.266591 -0.271030
# popularity    0.393472 -0.128508    1.000000  0.565704  0.056494
# revenue       0.662532 -0.266591    0.565704  1.000000  0.220411
# runtime       0.212593 -0.271030    0.056494  0.220411  1.000000
# vote_average -0.086869 -0.374041    0.124611  0.189580  0.371798
# vote_count    0.462440 -0.355514    0.580792  0.743435  0.215090
# isPopular     0.344382 -0.144797    0.474310  0.363234  0.010182
#
#               vote_average  vote_count  isPopular
# budget           -0.086869    0.462440   0.344382
# id               -0.374041   -0.355514  -0.144797
# popularity        0.124611    0.580792   0.474310
# revenue           0.189580    0.743435   0.363234
# runtime           0.371798    0.215090   0.010182
# vote_average      1.000000    0.417941   0.002566
# vote_count        0.417941    1.000000   0.402480
# isPopular         0.002566    0.402480   1.000000
# <AxesSubplot:>

# %%
# Draw pairs of variables against one another
sb.pairplot(data = df)

# %%
popz = pd.DataFrame(df['isPopular'])  # Response
revenue = pd.DataFrame(df['revenue'])      # Predictor

# %%
popz.value_counts()
# Out:
# isPopular
# 0            1466
# 1            1466
# dtype: int64

# %%
# Create a joint dataframe by concatenating saleprice and centralAir
trainDF = pd.concat([revenue, popz], axis = 1).reindex(revenue.index)

# Joint Boxplot of centralAir against saleprice
f = plt.figure(figsize=(18, 6))
sb.boxplot(x = "revenue", y = "isPopular", data = trainDF, orient = "h")

# Joint Swarmplot of Total Train against Legendary Train
f = plt.figure(figsize=(18, 6))
sb.swarmplot(x = "revenue", y = "isPopular", data = trainDF, orient = "h")
# Out:
# C:\Users\Wonseok\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Wonseok\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='revenue', ylabel='isPopular'>

# %% [markdown]
# ## Scikit learn
# Import Classification Tree model from Scikit-Learn : from sklearn.tree import DecisionTreeClassifier

# %%
 # Import Decision Tree Classifier model from Scikit-Learn
from sklearn.tree import DecisionTreeClassifier

# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 4)

# %%
from sklearn.model_selection import train_test_split

popz = pd.DataFrame(df['isPopular'])  # Response
revenue = pd.DataFrame(df['revenue'])      # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(revenue, popz, test_size = 0.25)

# %%
# Train the Decision Tree Classifier model
dectree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
# Plot the trained Decision Tree
from sklearn.tree import plot_tree

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=["isPopular"], 
          class_names=["N","Y"])
# Out:
# [Text(334.8, 587.0880000000001, 'isPopular <= 50006254.0\ngini = 0.5\nsamples = 2199\nvalue = [1116, 1083]\nclass = N'),
#  Text(167.4, 456.624, 'isPopular <= 8201617.5\ngini = 0.415\nsamples = 1193\nvalue = [842, 351]\nclass = N'),
#  Text(83.7, 326.1600000000001, 'isPopular <= 4604325.5\ngini = 0.244\nsamples = 359\nvalue = [308, 51]\nclass = N'),
#  Text(41.85, 195.69600000000003, 'isPopular <= 3.0\ngini = 0.191\nsamples = 234\nvalue = [209, 25]\nclass = N'),
#  Text(20.925, 65.23200000000008, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Y'),
#  Text(62.775000000000006, 65.23200000000008, 'gini = 0.185\nsamples = 233\nvalue = [209, 24]\nclass = N'),
#  Text(125.55000000000001, 195.69600000000003, 'isPopular <= 7882452.5\ngini = 0.329\nsamples = 125\nvalue = [99, 26]\nclass = N'),
#  Text(104.625, 65.23200000000008, 'gini = 0.368\nsamples = 103\nvalue = [78, 25]\nclass = N'),
#  Text(146.475, 65.23200000000008, 'gini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = N'),
#  Text(251.10000000000002, 326.1600000000001, 'isPopular <= 8890022.5\ngini = 0.461\nsamples = 834\nvalue = [534, 300]\nclass = N'),
#  Text(209.25, 195.69600000000003, 'isPopular <= 8653891.0\ngini = 0.48\nsamples = 20\nvalue = [8, 12]\nclass = Y'),
#  Text(188.32500000000002, 65.23200000000008, 'gini = 0.498\nsamples = 15\nvalue = [8, 7]\nclass = N'),
#  Text(230.175, 65.23200000000008, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Y'),
#  Text(292.95, 195.69600000000003, 'isPopular <= 12503094.0\ngini = 0.457\nsamples = 814\nvalue = [526, 288]\nclass = N'),
#  Text(272.02500000000003, 65.23200000000008, 'gini = 0.375\nsamples = 116\nvalue = [87, 29]\nclass = N'),
#  Text(313.875, 65.23200000000008, 'gini = 0.467\nsamples = 698\nvalue = [439, 259]\nclass = N'),
#  Text(502.20000000000005, 456.624, 'isPopular <= 186786496.0\ngini = 0.396\nsamples = 1006\nvalue = [274, 732]\nclass = Y'),
#  Text(418.5, 326.1600000000001, 'isPopular <= 120036288.0\ngini = 0.455\nsamples = 698\nvalue = [244, 454]\nclass = Y'),
#  Text(376.65000000000003, 195.69600000000003, 'isPopular <= 50741070.0\ngini = 0.471\nsamples = 487\nvalue = [185, 302]\nclass = Y'),
#  Text(355.725, 65.23200000000008, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Y'),
#  Text(397.575, 65.23200000000008, 'gini = 0.474\nsamples = 479\nvalue = [185, 294]\nclass = Y'),
#  Text(460.35, 195.69600000000003, 'isPopular <= 123291896.0\ngini = 0.403\nsamples = 211\nvalue = [59, 152]\nclass = Y'),
#  Text(439.425, 65.23200000000008, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Y'),
#  Text(481.27500000000003, 65.23200000000008, 'gini = 0.417\nsamples = 199\nvalue = [59, 140]\nclass = Y'),
#  Text(585.9, 326.1600000000001, 'isPopular <= 299711984.0\ngini = 0.176\nsamples = 308\nvalue = [30, 278]\nclass = Y'),
#  Text(544.0500000000001, 195.69600000000003, 'isPopular <= 297972016.0\ngini = 0.27\nsamples = 143\nvalue = [23, 120]\nclass = Y'),
#  Text(523.125, 65.23200000000008, 'gini = 0.262\nsamples = 142\nvalue = [22, 120]\nclass = Y'),
#  Text(564.975, 65.23200000000008, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = N'),
#  Text(627.75, 195.69600000000003, 'isPopular <= 368809904.0\ngini = 0.081\nsamples = 165\nvalue = [7, 158]\nclass = Y'),
#  Text(606.825, 65.23200000000008, 'gini = 0.153\nsamples = 60\nvalue = [5, 55]\nclass = Y'),
#  Text(648.6750000000001, 65.23200000000008, 'gini = 0.037\nsamples = 105\nvalue = [2, 103]\nclass = Y')]

# %%
# Predict centralAir corresponding to SalePrice
popz_train_pred = dectree.predict(X_train)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree.score(X_train, y_train))


# Plot the two-way Confusion Matrix
from sklearn.metrics import confusion_matrix
sb.heatmap(confusion_matrix(y_train, popz_train_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
# Out:
# Classification Accuracy 	: 0.7189631650750341
# <AxesSubplot:>

# %%
def tn_assign (y_train, prediction):
    TN = confusion_matrix(y_train, prediction)[0][0]
    FP = confusion_matrix(y_train, prediction)[0][1]
    FN = confusion_matrix(y_train, prediction)[1][0]
    TP = confusion_matrix(y_train, prediction)[1][1]
    print(TN)
    print(FP)
    print(FN)
    print(TP)
    return TN,FP,FN,TP

# %%
TN, FP, FN,TP = tn_assign(y_train, popz_train_pred)
# Out:
# 843
# 273
# 345
# 738

# %%
#True Positive Rate
def Rates(TN,FP,FN,TP):
    print("True Positive Rate  \t:", TP/(TP+FN))  
    print("True Negative Rate  \t:", TN/(TN+FP))
    print("False Positive Rate  \t:", FP/(TN+FP))
    print("False Negative Rate  \t:", FN/(TP+FN))
    return

# %%
Rates(TN,FP,FN,TP)
# Out:
# True Positive Rate  	: 0.6814404432132964
# True Negative Rate  	: 0.7553763440860215
# False Positive Rate  	: 0.2446236559139785
# False Negative Rate  	: 0.3185595567867036

# %% [markdown]
# # Test set

# %%
# Predict centralAir corresponding to saleprice (Test)
popz_test_pred = dectree.predict(X_test)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree.score(X_test, y_test))

# Plot the two-way Confusion Matrix
from sklearn.metrics import confusion_matrix
sb.heatmap(confusion_matrix(y_test, popz_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
# Out:
# Classification Accuracy 	: 0.723055934515689
# <AxesSubplot:>

# %%
TN, FP, FN,TP = tn_assign(y_test, popz_test_pred)
# Out:
# 264
# 86
# 117
# 266

# %%
Rates(TN,FP,FN,TP)
# Out:
# True Positive Rate  	: 0.6945169712793734
# True Negative Rate  	: 0.7542857142857143
# False Positive Rate  	: 0.24571428571428572
# False Negative Rate  	: 0.30548302872062666

# %% [markdown]
# # Multi-variate Decision Tree

# %%
print(df.dtypes)
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# keywords                 object
# isPopular                 int32
# dtype: object

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Extract Response and Predictors
y = pd.DataFrame(df['isPopular'])
X = pd.DataFrame(df[['budget', 'revenue', 'vote_average','vote_count','runtime']])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 360)

# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
# Plot the trained Decision Tree
from sklearn.tree import plot_tree

f = plt.figure(figsize=(24,24))
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=X_train.columns, 
          class_names=["N","Y"])
# Out:
# [Text(669.6, 1174.1760000000002, 'vote_count <= 1267.5\ngini = 0.5\nsamples = 2572\nvalue = [1280, 1292]\nclass = Y'),
#  Text(334.8, 913.248, 'vote_count <= 396.0\ngini = 0.435\nsamples = 1644\nvalue = [1119, 525]\nclass = N'),
#  Text(167.4, 652.3200000000002, 'vote_count <= 180.5\ngini = 0.278\nsamples = 731\nvalue = [609, 122]\nclass = N'),
#  Text(83.7, 391.39200000000005, 'revenue <= 372.0\ngini = 0.118\nsamples = 271\nvalue = [254, 17]\nclass = N'),
#  Text(41.85, 130.46400000000017, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Y'),
#  Text(125.55000000000001, 130.46400000000017, 'gini = 0.111\nsamples = 270\nvalue = [254, 16]\nclass = N'),
#  Text(251.10000000000002, 391.39200000000005, 'budget <= 3150000.0\ngini = 0.352\nsamples = 460\nvalue = [355, 105]\nclass = N'),
#  Text(209.25, 130.46400000000017, 'gini = 0.084\nsamples = 68\nvalue = [65, 3]\nclass = N'),
#  Text(292.95, 130.46400000000017, 'gini = 0.385\nsamples = 392\nvalue = [290, 102]\nclass = N'),
#  Text(502.20000000000005, 652.3200000000002, 'vote_average <= 6.55\ngini = 0.493\nsamples = 913\nvalue = [510, 403]\nclass = N'),
#  Text(418.5, 391.39200000000005, 'vote_average <= 6.05\ngini = 0.469\nsamples = 498\nvalue = [187, 311]\nclass = Y'),
#  Text(376.65000000000003, 130.46400000000017, 'gini = 0.401\nsamples = 267\nvalue = [74, 193]\nclass = Y'),
#  Text(460.35, 130.46400000000017, 'gini = 0.5\nsamples = 231\nvalue = [113, 118]\nclass = Y'),
#  Text(585.9, 391.39200000000005, 'budget <= 12650000.0\ngini = 0.345\nsamples = 415\nvalue = [323, 92]\nclass = N'),
#  Text(544.0500000000001, 130.46400000000017, 'gini = 0.198\nsamples = 215\nvalue = [191, 24]\nclass = N'),
#  Text(627.75, 130.46400000000017, 'gini = 0.449\nsamples = 200\nvalue = [132, 68]\nclass = N'),
#  Text(1004.4000000000001, 913.248, 'revenue <= 20022558.0\ngini = 0.287\nsamples = 928\nvalue = [161, 767]\nclass = Y'),
#  Text(837.0, 652.3200000000002, 'vote_count <= 2712.0\ngini = 0.494\nsamples = 72\nvalue = [40, 32]\nclass = N'),
#  Text(753.3000000000001, 391.39200000000005, 'vote_average <= 7.75\ngini = 0.403\nsamples = 50\nvalue = [36, 14]\nclass = N'),
#  Text(711.45, 130.46400000000017, 'gini = 0.484\nsamples = 34\nvalue = [20, 14]\nclass = N'),
#  Text(795.15, 130.46400000000017, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = N'),
#  Text(920.7, 391.39200000000005, 'runtime <= 92.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]\nclass = Y'),
#  Text(878.85, 130.46400000000017, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = N'),
#  Text(962.5500000000001, 130.46400000000017, 'gini = 0.198\nsamples = 18\nvalue = [2, 16]\nclass = Y'),
#  Text(1171.8, 652.3200000000002, 'vote_count <= 3280.0\ngini = 0.243\nsamples = 856\nvalue = [121, 735]\nclass = Y'),
#  Text(1088.1000000000001, 391.39200000000005, 'vote_average <= 7.15\ngini = 0.329\nsamples = 500\nvalue = [104, 396]\nclass = Y'),
#  Text(1046.25, 130.46400000000017, 'gini = 0.259\nsamples = 367\nvalue = [56, 311]\nclass = Y'),
#  Text(1129.95, 130.46400000000017, 'gini = 0.461\nsamples = 133\nvalue = [48, 85]\nclass = Y'),
#  Text(1255.5, 391.39200000000005, 'runtime <= 107.5\ngini = 0.091\nsamples = 356\nvalue = [17, 339]\nclass = Y'),
#  Text(1213.65, 130.46400000000017, 'gini = 0.161\nsamples = 125\nvalue = [11, 114]\nclass = Y'),
#  Text(1297.3500000000001, 130.46400000000017, 'gini = 0.051\nsamples = 231\nvalue = [6, 225]\nclass = Y')]

# %%
# Import the required metric from sklearn
from sklearn.metrics import confusion_matrix

# Predict the Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)

# Print the Classification Accuracy
print("Train Data")
print("Accuracy  :\t", dectree.score(X_train, y_train))
print()

# Print the Accuracy Measures from the Confusion Matrix
cmTrain = confusion_matrix(y_train, y_train_pred)
tpTrain = cmTrain[1][1] # True Positives : Y (1) predicted Y (1)
fpTrain = cmTrain[0][1] # False Positives : N (0) predicted Y (1)
tnTrain = cmTrain[0][0] # True Negatives : N (0) predicted N (0)
fnTrain = cmTrain[1][0] # False Negatives : Y (1) predicted N (0)

print("TPR Train :\t", (tpTrain/(tpTrain + fnTrain)))
print("TNR Train :\t", (tnTrain/(tnTrain + fpTrain)))
print()

print("FPR Train :\t", (fpTrain/(tnTrain + fpTrain)))
print("FNR Train :\t", (fnTrain/(tpTrain + fnTrain)))

# Plot the two-way Confusion Matrix
sb.heatmap(confusion_matrix(y_train, y_train_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
# Out:
# Train Data
# Accuracy  :	 0.7904354587869362
#
# TPR Train :	 0.8227554179566563
# TNR Train :	 0.7578125
#
# FPR Train :	 0.2421875
# FNR Train :	 0.17724458204334365
# <AxesSubplot:>

# %% [markdown]
# # Test

# %%
# Import the required metric from sklearn
from sklearn.metrics import confusion_matrix

# Predict the Response corresponding to Predictors
y_test_pred = dectree.predict(X_test)

# Print the Classification Accuracy
print("Test Data")
print("Accuracy  :\t", dectree.score(X_test, y_test))
print()

# Print the Accuracy Measures from the Confusion Matrix
cmTest = confusion_matrix(y_test, y_test_pred)
tpTest = cmTest[1][1] # True Positives : Y (1) predicted Y (1)
fpTest = cmTest[0][1] # False Positives : N (0) predicted Y (1)
tnTest = cmTest[0][0] # True Negatives : N (0) predicted N (0)
fnTest = cmTest[1][0] # False Negatives : Y (1) predicted N (0)

print("TPR Test :\t", (tpTest/(tpTest + fnTest)))
print("TNR Test :\t", (tnTest/(tnTest + fpTest)))
print()

print("FPR Test :\t", (fpTest/(fpTest + tnTest)))
print("FNR Test :\t", (fnTest/(fnTest + tpTest)))

# Plot the two-way Confusion Matrix
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
# Out:
# Test Data
# Accuracy  :	 0.7833333333333333
#
# TPR Test :	 0.8275862068965517
# TNR Test :	 0.7419354838709677
#
# FPR Test :	 0.25806451612903225
# FNR Test :	 0.1724137931034483
# <AxesSubplot:>

# %% [markdown]
# # Advanced techniques
# ???
